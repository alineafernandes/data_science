# %% [markdown]
# <a href="https://colab.research.google.com/github/alineafernandes/data_science/blob/main/Introducao_A_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
notas = pd.read_csv("ratings.csv")
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns = ["UsuárioID", "FilmeID", "Nota", "Momento"]
notas.head()
# Out:
#    UsuárioID  FilmeID  Nota    Momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas['Nota'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas['Nota'].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: Nota, dtype: int64

# %%
print('Média', notas['Nota'].mean())
print('Mediana', notas['Nota'].median())
# Out:
# Média 3.501556983616962
# Mediana 3.5

# %%
notas.Nota.head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: Nota, dtype: float64

# %%
notas.Nota.plot()
# Out:
# <Axes: >

# %%
notas.Nota.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
notas.Nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: Nota, dtype: float64

# %%
import seaborn as sns
sns.boxplot(notas.Nota)
# Out:
# <Axes: >

# %%
notas.nlargest(10,'Nota')
# Out:
#     UsuárioID  FilmeID  Nota    Momento
# 3           1       47   5.0  964983815
# 4           1       50   5.0  964982931
# 6           1      101   5.0  964980868
# 8           1      151   5.0  964984041
# 9           1      157   5.0  964984100
# 10          1      163   5.0  964983650
# 11          1      216   5.0  964981208
# 13          1      231   5.0  964981179
# 15          1      260   5.0  964981680
# 18          1      333   5.0  964981179

# %%
notas.nsmallest(10,'Nota')
# Out:
#      UsuárioID  FilmeID  Nota     Momento
# 261          3       31   0.5  1306463578
# 262          3      527   0.5  1306464275
# 263          3      647   0.5  1306463619
# 264          3      688   0.5  1306464228
# 265          3      720   0.5  1306463595
# 267          3      914   0.5  1306463567
# 268          3     1093   0.5  1306463627
# 269          3     1124   0.5  1306464216
# 270          3     1263   0.5  1306463569
# 271          3     1272   0.5  1306463624

# %%
filmes = pd.read_csv("movies.csv")
filmes.columns = ["FilmeID", "Titulo", "Generos"]
filmes.head()
# Out:
#    FilmeID                              Titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        Generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.head()
# Out:
#    UsuárioID  FilmeID  Nota    Momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %% [markdown]
# #Analisando algumas notas específicas por filme

# %%
notas.query('FilmeID==1').Nota.mean()
# Out:
# 3.9209302325581397

# %%
notas.query('FilmeID==2').Nota.mean()
# Out:
# 3.4318181818181817

# %%
medias_por_filme = notas.groupby('FilmeID').Nota.mean()
medias_por_filme.head()
# Out:
# FilmeID
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: Nota, dtype: float64

# %%
medias_por_filme.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: Nota, dtype: float64

# %%
sns.distplot(medias_por_filme)
# Out:
# <ipython-input-75-c99e5fbcf4e4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(medias_por_filme)
# <Axes: xlabel='Nota', ylabel='Density'>

# %%
import matplotlib.pyplot as plt
plt.hist(medias_por_filme)
plt.title("Histograma das médias dos filmes")
# Out:
# Text(0.5, 1.0, 'Histograma das médias dos filmes')

# %%
tmdb = pd.read_csv("tmdb_5000_movies.csv")
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.original_language.unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
tmdb.original_language.value_counts()
# Out:
# en    4505
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# cn      12
# ru      11
# ko      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: original_language, dtype: int64

# %%
tmdb.vote_average.unique()
# Out:
# array([ 7.2,  6.9,  6.3,  7.6,  6.1,  5.9,  7.4,  7.3,  5.7,  5.4,  7. ,
#         6.5,  6.4,  6.2,  7.1,  5.8,  6.6,  7.5,  5.5,  6.7,  6.8,  6. ,
#         5.1,  7.8,  5.6,  5.2,  8.2,  7.7,  5.3,  8. ,  4.8,  4.9,  7.9,
#         8.1,  4.7,  5. ,  4.2,  4.4,  4.1,  3.7,  3.6,  3. ,  3.9,  4.3,
#         4.5,  3.4,  4.6,  8.3,  3.5,  4. ,  2.3,  3.2,  0. ,  3.8,  2.9,
#         8.5,  1.9,  3.1,  3.3,  2.2,  0.5,  9.3,  8.4,  2.7, 10. ,  1. ,
#         2. ,  2.8,  9.5,  2.6,  2.4])

# %%
tmdb["original_language"].value_counts()
# Out:
# en    4505
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# cn      12
# ru      11
# ko      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: original_language, dtype: int64

# %%
tmdb["original_language"].value_counts().to_frame()
# Out:
#     original_language
# en               4505
# fr                 70
# es                 32
# zh                 27
# de                 27
# hi                 19
# ja                 16
# it                 14
# cn                 12
# ru                 11
# ko                 11
# pt                  9
# da                  7
# sv                  5
# nl                  4
# fa                  4
# th                  3
# he                  3
# ta                  2
# cs                  2
# ro                  2
# id                  2
# ar                  2
# vi                  1
# sl                  1
# ps                  1
# no                  1
# ky                  1
# hu                  1
# pl                  1
# af                  1
# nb                  1
# tr                  1
# is                  1
# xx                  1
# te                  1
# el                  1

# %%
tmdb["original_language"].value_counts().to_frame().reset_index()
# Out:
#    index  original_language
# 0     en               4505
# 1     fr                 70
# 2     es                 32
# 3     zh                 27
# 4     de                 27
# 5     hi                 19
# 6     ja                 16
# 7     it                 14
# 8     cn                 12
# 9     ru                 11
# 10    ko                 11
# 11    pt                  9
# 12    da                  7
# 13    sv                  5
# 14    nl                  4
# 15    fa                  4
# 16    th                  3
# 17    he                  3
# 18    ta                  2
# 19    cs                  2
# 20    ro                  2
# 21    id                  2
# 22    ar                  2
# 23    vi                  1
# 24    sl                  1
# 25    ps                  1
# 26    no                  1
# 27    ky                  1
# 28    hu                  1
# 29    pl                  1
# 30    af                  1
# 31    nb                  1
# ...

# %%
contagem_de_lingua = tmdb["original_language"].value_counts().to_frame().reset_index()
contagem_de_lingua.columns = ["original_language","total"]
contagem_de_lingua.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                zh     27
# 4                de     27

# %%
sns.barplot(x = 'original_language', y = 'total', data = contagem_de_lingua)
# Out:
# <Axes: xlabel='original_language', ylabel='total'>

# %%
sns.catplot(x= 'original_language', kind = "count", data = tmdb)

# %%
total_por_lingua = tmdb["original_language"].value_counts()
total_geral = total_por_lingua.sum()
total_de_ingles = total_por_lingua.loc["en"]
total_do_resto = total_geral - total_de_ingles
print(total_de_ingles, total_do_resto)
# Out:
# 4505 298

# %%
dados = {
    'lingua' : ['ingles','outros'],
    'total' : [total_de_ingles, total_do_resto]
}
dados = pd.DataFrame(dados)
sns.barplot(x = "lingua", y = "total", data = dados)
# Out:
# <Axes: xlabel='lingua', ylabel='total'>

# %%
total_por_lingua_de_outros_filmes = tmdb.query("original_language != 'en'").original_language.value_counts()
total_por_lingua_de_outros_filmes
# Out:
# fr    70
# es    32
# zh    27
# de    27
# hi    19
# ja    16
# it    14
# cn    12
# ko    11
# ru    11
# pt     9
# da     7
# sv     5
# fa     4
# nl     4
# he     3
# th     3
# ro     2
# id     2
# ar     2
# cs     2
# ta     2
# tr     1
# nb     1
# af     1
# pl     1
# is     1
# hu     1
# vi     1
# ky     1
# xx     1
# te     1
# no     1
# sl     1
# ps     1
# el     1
# Name: original_language, dtype: int64

# %%
filmes_sem_lingua_original_em_ingles = tmdb.query("original_language != 'en'")
sns.catplot(x= 'original_language', kind = "count",
            data = filmes_sem_lingua_original_em_ingles,
            aspect = 2,
            palette = "crest_r",
            order = total_por_lingua_de_outros_filmes.index)

# %%
filmes.head(2)
# Out:
#    FilmeID            Titulo                                      Generos
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
notas_do_toy_story = notas.query("FilmeID == 1")
notas_do_jumanji = notas.query("FilmeID == 2")
print(len(notas_do_toy_story), len(notas_do_jumanji))
# Out:
# 215 110

# %%
print("Nota média do Toy Story %.2f"% notas_do_toy_story.Nota.mean())
print("Nota média do Jumanji %.2f"% notas_do_jumanji.Nota.mean())
# Out:
# Nota média do Toy Story 3.92
# Nota média do Jumanji 3.43

# %%
print("Nota mediana do Toy Story %.2f"% notas_do_toy_story.Nota.median())
print("Nota mediana do Jumanji %.2f"% notas_do_jumanji.Nota.median())
# Out:
# Nota mediana do Toy Story 4.00
# Nota mediana do Jumanji 3.50

# %%
plt.boxplot([notas_do_toy_story.Nota, notas_do_jumanji.Nota])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d8ceb2f87f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d8ceb2f8d30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d8ceb2f8550>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7d8ceb2f9270>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7d8ceb2f9510>,
# ...
#  'means': []}

# %%
print(notas_do_toy_story.Nota.std(), notas_do_jumanji.Nota.std())
# Out:
# 0.8348591407114047 0.8817134921476455
